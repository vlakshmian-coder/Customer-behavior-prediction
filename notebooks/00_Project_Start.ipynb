# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)

# Load customer features
customer_df = pd.read_csv("../data/processed/customer_features.csv")

print("=" * 50)
print("VANTARA PROJECT LOADED SUCCESSFULLY")
print("=" * 50)

print(f"\nShape: {customer_df.shape}")

print("\nColumns:")
print(customer_df.columns.tolist())

customer_df.head()
# Out:
# ==================================================
# VANTARA PROJECT LOADED SUCCESSFULLY
# ==================================================
#
# Shape: (5942, 16)
#
# Columns:
# ['Customer ID', 'TotalSpend', 'TotalOrders', 'TotalProducts', 'AverageOrderValue', 'FirstPurchase_x', 'LastPurchase_x', 'CustomerTenure', 'FirstPurchase_y', 'LastPurchase_y', 'FirstPurchase', 'LastPurchase', 'TenureMonths', 'PurchaseFrequencyPerMonth', 'AverageSpendPerProduct', 'AverageQuantityPerOrder']
#    Customer ID  TotalSpend  TotalOrders  TotalProducts  AverageOrderValue  \
# 0      12346.0      -64.68           17             52          -1.347500
# 1      12347.0     5633.32            8           3286          22.266087
# 2      12348.0     2019.40            5           2714          39.596078
# 3      12349.0     4404.54            5           1619          24.469667
# 4      12350.0      334.40            1            197          19.670588
#
#        FirstPurchase_x       LastPurchase_x  CustomerTenure  \
# 0  2009-12-14 08:34:00  2011-01-18 10:17:00             400
# 1  2010-10-31 14:20:00  2011-12-07 15:52:00             402
# 2  2010-09-27 14:59:00  2011-09-25 13:13:00             362
# 3  2009-12-04 12:49:00  2011-11-21 09:51:00             716
# 4  2011-02-02 16:01:00  2011-02-02 16:01:00               0
#
#        FirstPurchase_y       LastPurchase_y        FirstPurchase  \
# 0  2009-12-14 08:34:00  2011-01-18 10:17:00  2009-12-14 08:34:00
# 1  2010-10-31 14:20:00  2011-12-07 15:52:00  2010-10-31 14:20:00
# 2  2010-09-27 14:59:00  2011-09-25 13:13:00  2010-09-27 14:59:00
# 3  2009-12-04 12:49:00  2011-11-21 09:51:00  2009-12-04 12:49:00
# 4  2011-02-02 16:01:00  2011-02-02 16:01:00  2011-02-02 16:01:00
#
#           LastPurchase  TenureMonths  PurchaseFrequencyPerMonth  \
# 0  2011-01-18 10:17:00     13.333333                   1.275000
# 1  2011-12-07 15:52:00     13.400000                   0.597015
# 2  2011-09-25 13:13:00     12.066667                   0.414365
# 3  2011-11-21 09:51:00     23.866667                   0.209497
# 4  2011-02-02 16:01:00      1.000000                   1.000000
#
#    AverageSpendPerProduct  AverageQuantityPerOrder
# 0               -1.243846                 3.058824
# 1                1.714340               410.750000
# 2                0.744068               542.800000
# 3                2.720531               323.800000
# 4                1.697462               197.000000
